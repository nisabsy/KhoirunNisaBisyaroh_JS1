# %% [markdown]
# <a href="https://colab.research.google.com/github/nisabsy/KhoirunNisaBisyaroh_JS1/blob/main/KLASIFIKASI%20DATA%20SERANGAN%20JANTUNG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **KLASIFIKASI SERANGAN JANTUNG**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv('heart.csv')
data.head(25)
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40   M           ATA        140          289          0     Normal
# 1    49   F           NAP        160          180          0     Normal
# 2    37   M           ATA        130          283          0         ST
# 3    48   F           ASY        138          214          0     Normal
# 4    54   M           NAP        150          195          0     Normal
# 5    39   M           NAP        120          339          0     Normal
# 6    45   F           ATA        130          237          0     Normal
# 7    54   M           ATA        110          208          0     Normal
# 8    37   M           ASY        140          207          0     Normal
# 9    48   F           ATA        120          284          0     Normal
# 10   37   F           NAP        130          211          0     Normal
# 11   58   M           ATA        136          164          0         ST
# ...

# %%
print('==================== Pre-Processing ====================')
#pengecekan ada data kosong atau tidak
print(data.isnull().any())
print(data.isnull().sum())
# Out:
# ==================== Pre-Processing ====================
# Age               False
# Sex               False
# ChestPainType     False
# RestingBP         False
# Cholesterol       False
# FastingBS         False
# RestingECG        False
# MaxHR             False
# ExerciseAngina    False
# Oldpeak           False
# ST_Slope          False
# HeartDisease      False
# dtype: bool
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
data['Age'] = enc.fit_transform(data['Age'].values)
data['Sex'] = enc.fit_transform(data['Sex'].values)
data['ChestPainType'] = enc.fit_transform(data['ChestPainType'].values)
data['RestingBP'] = enc.fit_transform(data['RestingBP'].values)
data['Cholesterol'] = enc.fit_transform(data['Cholesterol'].values)
data['FastingBS'] = enc.fit_transform(data['FastingBS'].values)
data['RestingECG'] = enc.fit_transform(data['RestingECG'].values)
data['MaxHR'] = enc.fit_transform(data['MaxHR'].values)
data['ExerciseAngina'] = enc.fit_transform(data['ExerciseAngina'].values)
data['Oldpeak'] = enc.fit_transform(data['Oldpeak'].values)
data['ST_Slope'] = enc.fit_transform(data['ST_Slope'].values)

# %%
trs_data = data.drop(columns='HeartDisease')
trs_data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   12    1              1         41          147          0           1
# 1   21    0              2         55           40          0           1
# 2    9    1              1         31          141          0           2
# 3   20    0              0         39           72          0           1
# 4   26    1              2         49           53          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# 0     98               0       10         2
# 1     82               0       20         1
# 2     25               0       10         2
# 3     34               1       25         1
# 4     48               0       10         2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# ...

# %%
lbl_data = data['HeartDisease']
lbl_data.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: HeartDisease, dtype: int64

# %%
#membagi data menjadi data training dan data testing -> 0.3 data test 0.7 data train dan dirandom sebanyak 50
x_train,x_test,y_train,y_test=train_test_split(trs_data,lbl_data,test_size=0.9,random_state=500)
classifier = GaussianNB()
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)

# %%
print('Accuracy of Naive Bayes Kontinu classifier on test set: {:.2f}'.format(classifier.score(x_test,y_test)))
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
hasilpengujian = classification_report(y_test,y_pred)
print(hasilpengujian)
# Out:
# Accuracy of Naive Bayes Kontinu classifier on test set: 0.82
# [[286  88]
#  [ 61 392]]
# 0.8198307134220073
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79       374
#            1       0.82      0.87      0.84       453
#
#     accuracy                           0.82       827
#    macro avg       0.82      0.82      0.82       827
# weighted avg       0.82      0.82      0.82       827

# %%
k_rng = range(2,10)
sse = []
for k in k_rng:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(x_train, y_train)
  pred = knn.predict(x_test)
  k=+k
  print('Accuracy of K-NN classifier on test set with K = ',k,'Is : {:.2f}'.format(knn.score(x_test, y_test)))
# Out:
# Accuracy of K-NN classifier on test set with K =  2 Is : 0.69
# Accuracy of K-NN classifier on test set with K =  3 Is : 0.71
# Accuracy of K-NN classifier on test set with K =  4 Is : 0.73
# Accuracy of K-NN classifier on test set with K =  5 Is : 0.73
# Accuracy of K-NN classifier on test set with K =  6 Is : 0.73
# Accuracy of K-NN classifier on test set with K =  7 Is : 0.71
# Accuracy of K-NN classifier on test set with K =  8 Is : 0.72
# Accuracy of K-NN classifier on test set with K =  9 Is : 0.70

# %%
#proses KNN klasifikasi
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(x_train,y_train)
pred = knn.predict(x_test)

# %%
#hasil evaluasi KNN
print('Accuracy of K-NN classifier on test set: {:.2f}'.format(knn.score(x_test,y_test)))
print(confusion_matrix(y_test,pred))
print(accuracy_score(y_test,pred))
hasilpengujian2 = classification_report(y_test,pred)
print(hasilpengujian2)
# Out:
# Accuracy of K-NN classifier on test set: 0.73
# [[264 110]
#  [113 340]]
# 0.7303506650544136
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70       374
#            1       0.76      0.75      0.75       453
#
#     accuracy                           0.73       827
#    macro avg       0.73      0.73      0.73       827
# weighted avg       0.73      0.73      0.73       827
